# %%
import numpy as np
celsius_temp = np.array([56.7, 55.0, 54.4, 53.7, 50.0])

Fahrenheit = np.array(celsius_temp * 1.8 + 32)

print(Fahrenheit)
# Out:
# [134.06 131.   129.92 128.66 122.  ]

# %%
lap_times = np.array([75.5, 72.3, 71.8, 73.1, 70.9])

print("Shape: ",lap_times.shape)
print("Size: ",lap_times.size)
print("Data Type: ",lap_times.dtype)

# convert second -> minutes
lap_times_minutes = lap_times / 60

print(f"Lap ")
# Out:
# Shape:  (5,)
# Size:  5
# Data Type:  float64
