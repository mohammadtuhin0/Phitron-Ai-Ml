# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("titanic_data_updated.csv")
df.head()
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
# 3            4      yes  first
# 4            5       no  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.sample(10)
# Out:
#      PassengerId Survived  Pclass                                    Name  \
# 360          361       no   third                      Skoog, Mr. Wilhelm
# 73            74       no   third             Chronopoulos, Mr. Apostolos
# 158          159       no   third                     Smiljanic, Mr. Mile
# 317          318       no  second                    Moraweck, Dr. Ernest
# 776          777       no   third                        Tobin, Mr. Roger
# 689          690      yes   first       Madill, Miss. Georgette Alexandra
# 439          440       no  second  Kvillner, Mr. Johan Henrik Johannesson
# 70            71       no  second              Jenkin, Mr. Stephen Curnow
# 309          310      yes   first          Francatelli, Miss. Laura Mabel
# 645          646      yes   first               Harper, Mr. Henry Sleeper
#
#         Sex   Age  SibSp  Parch      Ticket      Fare Cabin Embarked
# 360    male  40.0      1      4      347088   27.9000   NaN        S
# 73     male  26.0      1      0        2680   14.4542   NaN        C
# 158    male   NaN      0      0      315037    8.6625   NaN        S
# 317    male  54.0      0      0       29011   14.0000   NaN        S
# 776    male   NaN      0      0      383121    7.7500   F38        Q
# 689  female  15.0      0      1       24160  211.3375    B5        S
# 439    male  31.0      0      0  C.A. 18723   10.5000   NaN        S
# 70     male  32.0      0      0  C.A. 33111   10.5000   NaN        S
# 309  female  30.0      0      0    PC 17485   56.9292   E36        C
# 645    male  48.0      1      0    PC 17572   76.7292   D33        C

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()

df.drop_duplicates(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    object
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 83.7+ KB

# %%
# statistical

df.describe()
# Out:
#        PassengerId         Age       SibSp       Parch        Fare
# count   891.000000  714.000000  891.000000  891.000000  891.000000
# mean    446.000000   29.699118    0.523008    0.381594   32.204208
# std     257.353842   14.526497    1.102743    0.806057   49.693429
# min       1.000000    0.420000    0.000000    0.000000    0.000000
# 25%     223.500000   20.125000    0.000000    0.000000    7.910400
# 50%     446.000000   28.000000    0.000000    0.000000   14.454200
# 75%     668.500000   38.000000    1.000000    0.000000   31.000000
# max     891.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# <!-- 2.2 & 2.3 Multivariate Analysis- 1 ( Countplot with Hue ) -->

# %% [markdown]
# # Multivariate Analysis

# %% [markdown]
# ## 2.2 & 2.3 Multivariate Analysis- 1 (Countplot with Hue)

# %%
sns.countplot(x = df['Sex'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
gender_split = df.groupby('Sex') ['Survived'].value_counts(normalize=True)

print(gender_split)
# Out:
# Sex     Survived
# female  yes         0.742038
#         no          0.257962
# male    no          0.811092
#         yes         0.188908
# Name: proportion, dtype: float64

# %%
sns.countplot(x = df['Pclass'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
pclass_split = df.groupby('Pclass') ['Survived'].value_counts(normalize=True)

print(pclass_split)
# Out:
# Pclass  Survived
# first   yes         0.629630
#         no          0.370370
# second  no          0.527174
#         yes         0.472826
# third   no          0.757637
#         yes         0.242363
# Name: proportion, dtype: float64

# %% [markdown]
# # 2.4 Multi Variate Analysis -3 (Barplot for Cat-Num)

# %%
sns.countplot(x = df['Embarked'], hue=df['Survived'])
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %%
Embarked_split = df.groupby('Embarked') ['Survived'].value_counts(normalize=True)

print(Embarked_split)
# Out:
# Embarked  Survived
# C         yes         0.553571
#           no          0.446429
# Q         no          0.610390
#           yes         0.389610
# S         no          0.663043
#           yes         0.336957
# Name: proportion, dtype: float64

# %%
sns.barplot(x = df['Pclass'], y=df['Fare'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
sns.barplot(x = df['Survived'], y = df['Age'], hue=df['Sex'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %% [markdown]
# ## 2.6 Multivariate Analysis -4 ( KDE plot for categorical discrepancy )

# %%
sns.kdeplot(data = df, x = 'Age', hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(data = df, x = 'Fare', hue='Sex')
# Out:
# <Axes: xlabel='Fare', ylabel='Density'>

# %% [markdown]
# # 2.7 Multivariate Analysis -5 (Scatterplot)

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(data = df, 
                x = 'total_bill', 
                y = 'tip', 
                hue='sex',
                size = 'size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2.8 Y Data Profiling

# %%
df = pd.read_csv('titanic_data_updated.csv')

# %%
df.head(3)
# Out:
#    PassengerId Survived Pclass  \
# 0            1       no  third
# 1            2      yes  first
# 2            3      yes  third
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
from ydata_profiling import ProfileReport

profile = ProfileReport(df, title='Titanic Profile Report')

profile.to_file('my_report.html')
# Out:
# Summarize dataset:  29%|██████████▎                        | 5/17 [00:00<00:00, 17.45it/s, Describe variable: Embarked]
# Summarize dataset:  41%|██████████████▍                    | 7/17 [00:00<00:00, 15.18it/s, Describe variable: Embarked]
# 100%|██████████████████████████████████████████████████████████████████████████████████| 12/12 [00:00<00:00, 68.56it/s]
# Summarize dataset: 100%|████████████████████████████████████████████████████| 47/47 [00:03<00:00, 13.53it/s, Completed]
# Generate report structure: 100%|█████████████████████████████████████████████████████████| 1/1 [00:03<00:00,  3.26s/it]
# Render HTML: 100%|███████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  1.21it/s]
# Export report to file: 100%|█████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 49.11it/s]
