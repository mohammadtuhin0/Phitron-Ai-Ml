# %% [markdown]
# Variables and Data Type

# %%
phone_number = 17700240
print(phone_number)
# Out:
# 17700240

# %%
name = "Phitron"
print(name)
# Out:
# Phitron

# %%
age = 20
height = 5.6
name = "Tuhin"
is_passed = True

print(type(age), type(height), type(name), (is_passed))

age = 20.5
print(type(age))
# Out:
# <class 'int'> <class 'float'> <class 'str'> True
# <class 'float'>

# %% [markdown]
# Taking Input in Python

# %%
name = input("What is your name ?")

print(name)
# Out:
# What is your name ? Tuhin
# Tuhin

# %%
age = input("Age ?")

print(age, type(age))
# Out:
# Age ? 21
# 21 <class 'str'>

# %%
height = input("Height ?")

print(height, type(height))
# Out:
# Height ? 5.6
# 5.6 <class 'str'>

# %%
height = float(input("Height ?"))

print(height, type(height))

height = height + 0.2
print(height)
# Out:
# Height ? 5.4
# 5.4 <class 'float'>
# 5.6000000000000005

# %% [markdown]
# Operations in Python

# %%
x = 10; y = 3
sum = x + y
sub = x - y
mult = x * y
div = round(x / y, 2)

rem = x % y

print(sum , sub, mult, div, rem)
# Out:
# 13 7 30 3.33 1

# %%
x = 10; y = 3

greater_than = x > y
greater_than_equal = (10 >= 10)

print(greater_than, greater_than_equal)

less_than = x < y
less_than_equal = (10 <= 10)

print(less_than, less_than_equal)

equal = x == y
print(equal)

not_equal = x != y
print(not_equal)
# Out:
# True True
# False True
# False
# True

# %% [markdown]
# Logical Operation

# %%
x = 10; y = 5; z = 3

result = (x > y) and (x > z)
print(result)
# Out:
# True

# %%
x = 10; y = 5; z = 15
result = (x > y) and (x > z)

print(result)
# Out:
# False

# %%
x = 10; y = 5; z = 15
result = (x > y) or (x > z)

print(result)
# Out:
# True

# %%
x = 10 ; y = 20 ; z = 15
result = (x > y) or (x > z) 


print(result)
# Out:
# False

# %% [markdown]
# Precedence and Associativity

# %%
eq = 10 + 10/2 - 5*2
print(eq)

eq = (10+10) / 2 - 5 * 2
print(eq)
# Out:
# 5.0
# 0.0

# %% [markdown]
# Problem : Digit Summation

# %%
inp = input()
numbers = inp.split()

x = int(numbers[0])
y = int(numbers[1])

last_digit_of_x = x % 10
last_digit_of_y = y % 10

sum = last_digit_of_x + last_digit_of_y
print(sum)
# Out:
#  12 6
# 8
