# %% [markdown]
# # Class, Object and Instance

# %%
class Dog:
    pass

# %%
dog1 = Dog()
dir(dog1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
class Dog:
    pass

dog1 = Dog()
dog1.name = "dog1"
dog1.age = 20

# %%
print(dog1.name, dog1.age)
# Out:
# dog1 20

# %%
class Dog:
    # constructor
    def __init__(self):
        print("Hello constructor")

dog1 = Dog()
# Out:
# Hello constructor

# %%
class Dog:
    # constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def speak(self):
        print("Dog Speaking")

dog1 = Dog("DogName", 19)
dir(dog1)
print(dog1.name, dog1.age)
dog1.speak()
# Out:
# DogName 19
# Dog Speaking

# %%
class Dog:
    # constructor
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def speak(self):
        print("Dog Speaking")

dog1 = Dog("DogName", 31)
dog2 = Dog("DogName2", 19)

print(dog1.name, dog2.name)
# Out:
# DogName DogName2

# %%
class Dog:
    # constructor
    def __init__(self, name, age):
        self.name = name   # instance attribute
        self.age = age     # instance attribute

    def speak(self):       # instance attribute
        print(f"{self.name} Dog Speaking")

dog1 = Dog("DogName", 31)
dog2 = Dog("DogName2", 19)

dog1.speak()
dog2.speak()
# Out:
# DogName Dog Speaking
# DogName2 Dog Speaking

# %%
class Dog:
    food = "Apple"    # class attribute

    # constructor
    def __init__(self, name, age):
        self.name = name # instance attribute
        self.age = age

    def speak(self):
        print(f"{self.name} Dog speaking")

dog1 = Dog("DogName", 20)
dog2 = Dog("DogName2", 60)

print(dog1.food)
print(dog2.food)
# Out:
# Apple
# Apple

# %%
class Dog:
    food = "Apple"    # class attribute

    # constructor
    def __init__(self, name, age):
        self.name = name # instance attribute
        self.age = age

    def speak(self):
        print(f"{self.name} Dog speaking {self.food}")

    @classmethod
    def work(cls):          # class method = class attr
        print("Hello, dog", cls.food)

dog1 = Dog("DogName", 20)
dog2 = Dog("DogName2", 60)

dog1.speak()
dog1.work()
# Out:
# DogName Dog speaking Apple
# Hello, dog Apple

# %% [markdown]
# # Inheritance

# %%
## Inherit (single inheritance)
## parent Class / Base class / Super class

class Car:
    def __init__(self, windows, door, enginetype) -> None:
        self.windows = windows
        self.door = door
        self.enginetype = enginetype

    def drive(self):
        print(f"The person will drive the {self.enginetype} card")

car1 = Car("", "", "")
dir(car1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'door',
#  'drive',
#  'enginetype',
#  'windows']

# %%
# Derived / Child / subclass

class Tesla(Car):
    def __init__(self, windows, door, enginetype, is_selfDriving):
        super().__init__(windows, door, enginetype)
        self.is_selfDriving = is_selfDriving

tesla = Tesla(4, 2, "AB", True)
dir(tesla)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'door',
#  'drive',
#  'enginetype',
#  'is_selfDriving',
#  'windows']

# %%
class Farari(Car):
    def __init__(self, windows, door, enginetype, is_flying) -> None:
        super().__init__(windows, door, enginetype)
        self.is_flying = is_flying

# %%
## Multiple Inheritance
## When a class inherits from more than one base class

## Base class 1
class Animal:
    def __init__(self, name) -> None:
        self.name = name

    def eat(self):
        print(f"{self.name} is eating from Animal Base Class")


# Base class 2
class Pet:
    def __init__(self, owner) -> None:
        self.owner = owner

class Dog(Animal, Pet, ):
    def __init__(self, name, owner) -> None:
        Animal.__init__(self, name)
        Pet.__init__(self, owner)

dog1 = Dog("AB", "CD")
dir(dog1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'eat',
#  'name',
#  'owner']

# %% [markdown]
# # Polymorphism

# %%
# Base class
class Animal:
    def speak(self):
        return "Sound of the animal"

# Derive class
class Dog(Animal):
    def speak1(self):
        return "Dog Sound"

dog1 = Dog()
print(dog1.speak())
dir(dog1)
# Out:
# Sound of the animal
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'speak',
#  'speak1']

# %% [markdown]
# # Encapsulation

# %%
class Person:
    def __init__(self, name, age, balance):
        self.name = name         # public variables
        self.age = age           # public variables
        self.balance = balance

person1 = Person("Tuhin", 20, 133)
print(person1.name, person1.age, person1.balance)
person1.balance = 500000
print(person1.name, person1.age, person1.balance)
# Out:
# Tuhin 20 133
# Tuhin 20 500000

# %%
class Person:
    def __init__(self, name, age, balance):
        self.name = name         # public variables
        self.age = age           # public variables
        self.__balance = balance   # private variables

    def balanceCheck(self):
        return f"Your balance is : {self.__balance}"

    def get_balance(self):
        # conditions
        # if()
        return self.__balance

    def set_balance(self):
        # if()
        self.__balance += money

person1 = Person("Tuhin", 20, 4300)
print(person1.name, person1.balanceCheck())
# Out:
# Tuhin Your balance is : 4300

# %% [markdown]
# # Abstraction

# %%
from abc import ABC, abstractmethod

# Abstract class 
class Vehical(ABC):

    @abstractmethod
    def run(self):
        pass

# %%
class Car(Vehical):
    def start(self):
        print("Car is starting")

    def run(self):
        print("Car is running")

car1 = Car()
car1.start()
car1.run()
# Out:
# Car is starting
# Car is running

# %% [markdown]
# # Mini Project

# %%
# Abstraction class

class BankService(ABC):
    def run(self):
        print("Running")

    @abstractmethod
    def transaction(self):
        pass

class Account:
    bank_name = "Phitron Bank"

    def __init__(self, name, account_no, balance):
        self.name = name
        self.account_no = account_no
        self.__balance = balance

    def get_balance(self):
        return self.__balance

    def deposite(self, money):
        # extra security
        self.__balance += money
        return f"{money} is added, New balance is: {self.__balance}"

    def withdraw(self, withdrawMoney):
        if withdrawMoney > self.__balance:
            return f"insufficient Balance"
        self.__balance -= withdrawMoney
        return f"{withdrawMoney} is Withdrawed, New Balance is: {self.__balance}"

class SavingAccount(Account):
    def __init__(self, name, account_no, balance, interest_rate):
        super().__init__(name, account_no, balance)
        self.interest_rate = interest_rate

    def calculate_interest_rate(self):
        interest = self.get_balance() * self.interest_rate / 100
        return f"Interest rate is: {interest}"


class CurrentAccount(Account):
    def __init__(self, name, account_no, balance, overlimit):
        super().__init__(name, account_no, balance)
        self.overlimit = overlimit

    def withdraw(self, withdrawMoney):
        if withdrawMoney > self.get_balance() + self.overlimit:
            return f"Insufficient Balance for Current Account user"
        balance = self.get_balance() - withdrawMoney
        return f"{withdrawMoney} is withdrawed, new balance is {balance}"

class ATM(BankService):
    def transaction(self):
        print("Transaction by ATM")

    def withdraw(self):
        print("Withdraw")

class VisaCard(BankService):
    def transaction(self):
        super().transaction()
        print("Transaction by VisaCard")

# %%
saving1 = SavingAccount("Tuhin", 52, 5000, 0.9)
saving1.get_balance()
print(saving1.calculate_interest_rate())
saving1.withdraw(10000)
# Out:
# Interest rate is: 45.0
# 'insufficient Balance'

# %%
current1 = CurrentAccount("C", 52, 100, 500)
current1.withdraw(1000)
# Out:
# 'Insufficient Balance for Current Account user'
